# %% [markdown]
# # WeRateDogs Insights
# #### by: Mostafa Mohammad Bestawy Elnoby
# #### March 2021

# %% [markdown]
# #### This report explains some insights and relationships for Udacity Data professional Nanodegree Program, Project 2 "Wrangle and Analysis Data"

# %% [markdown]
# ## 1.Retweet Count and Favorite Count Relationship

# %% [markdown]
# #### as excpected, a good tweet has more interactions.as illustrated in Fig.1 there is a positive relationship between retweet count and  favorite count which represemt users interactions with the tweet

# %%
# Out:
# Text(0.5, -0.1, 'Fig.1 Positive Relationship between Favorite Count and Retweet Count')

# %% [markdown]
# ## 2.High Rating stages
# ### as illustared in Fig.2 doggo stage has the highest rating with average rating of 11.84,then pupper and lastly puppo

# %% [markdown]
# ## 3.High Interactions Breeds
# ### as illustared in Fig.3 the top 10 breeds have interactions

# %% [markdown]
# ## 4.High Rating Breeds
# ### as illustared in Fig.4 the top 10 breeds have higher ratings averages

# %% [markdown]
# ## 5.Tweets with images
# ### as illustared in Fig.5 a tweet with an image is better than without on behave of ratings

# %% [markdown]
# ## 6.WeRateDogs trend
# ### as illustared in Fig.6 WeRateDogs have ascending trend over time

# %%
# Out:
# Text(0.5, -0.15, 'Fig.6 Interaction over time')

# %% [markdown]
# ## 7.Best Names
# ### as illustared in Fig.7 let's suggest some best names to have higher ratings
# ###### copper, lucy, oliver,charlie,prnny,tucker,winston,lola and sadie
